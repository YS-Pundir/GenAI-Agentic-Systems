# %%
from sentence_transformers import SentenceTransformer  # Import the library that can load ready-made embedding models.
model_name = "sentence-transformers/all-MiniLM-L6-v2"  # Choose a popular Hugging Face model that creates 384-number vectors.
model = SentenceTransformer(model_name)  # Download and load the embedding model on your machine.
sentences = [  # Create a small list of text inputs, similar to chunks in a real RAG system.
    "How do I return a product?",  # First sentence is about product returns.
    "What is the refund policy?",  # Second sentence is about a related refund topic.
    "When is the Module 3 capstone viva?",
    "Refunds are processed within seven working days."  # Third sentence is unrelated to refunds.
]  # End the list of input sentences.
embeddings = model.encode(sentences)  # Convert every sentence into one numeric vector.
print("--- Text to embeddings ---")  # Print a heading so the output is easy to read.
for sentence, vector in zip(sentences, embeddings):  # Go through each sentence together with its vector.
    print("Sentence:", sentence)  # Show the original sentence.
    print("Vector length:", len(vector))  # Show how many numbers are inside the vector.
    print("First 5 numbers:", vector[:5])  # Show only the first few numbers because the full vector is long.
    print()  # Add a blank line between outputs.
print("--- What this means for RAG ---")  # Print a heading for the final explanation.
print("Return + refund sentences are about similar topics,")  # Explain why related sentences matter.
print("so their vectors sit CLOSER in meaning-space than the viva sentence.")  # Connect the vector idea to meaning.
print("Upcoming sessions: store these vectors in a vector DB and SEARCH them.")  # Connect today's demo to full RAG.
print()
print("----Explaination to the Question----")
print("After the vector is created , these will be stored in Vector database ,\nLater on these will br retrieved from vector db and will be added to the prompt as a context to generate the answers . ")
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lenovo\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 6149.13it/s]
# --- Text to embeddings ---
# Sentence: How do I return a product?
# Vector length: 384
# First 5 numbers: [-0.0014792   0.00484184  0.01843752 -0.04052044  0.00651551]
#
# Sentence: What is the refund policy?
# Vector length: 384
# First 5 numbers: [-0.09238822  0.05380009  0.04620504  0.02937884  0.04612401]
#
# Sentence: When is the Module 3 capstone viva?
# Vector length: 384
# First 5 numbers: [-0.02387593  0.00036229 -0.07705002 -0.03489099  0.04409402]
#
# Sentence: Refunds are processed within seven working days.
# Vector length: 384
# First 5 numbers: [-0.06925714 -0.0039541   0.08934963  0.01417763  0.03511774]
#
# --- What this means for RAG ---
# Return + refund sentences are about similar topics,
# so their vectors sit CLOSER in meaning-space than the viva sentence.
# Upcoming sessions: store these vectors in a vector DB and SEARCH them.
#
# ----Explaination to the Question----
# After the vector is created , these will be stored in Vector database ,
# Later on these will br retrieved from vector db and will be added to the prompt as a context to generate the answers .

# %%
from sentence_transformers import SentenceTransformer

model_name = "sentence-transformers/all-MiniLM-L6-v2" 

model=SentenceTransformer(model_name)

sentences= [  # Create a small list of text inputs, similar to chunks in a real RAG system.
    "How do I return a product?",  # First sentence is about product returns.
    "What is the refund policy?",  # Second sentence is about a related refund topic.
    "When is the Module 3 capstone viva?",
    "Refunds are processed within seven working days."  # Third sentence is unrelated to refunds.
] 

embeddings=model.encode(sentences)

for sentence,vector in zip(sentences,embeddings):
    print("the length of a vector: ",len(vector))
    print(sentence,":\n",vector[:4])
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 8960.52it/s]
# the length of a vector:  384
# How do I return a product? :
#  [-0.0014792   0.00484184  0.01843752 -0.04052044]
# the length of a vector:  384
# What is the refund policy? :
#  [-0.09238822  0.05380009  0.04620504  0.02937884]
# the length of a vector:  384
# When is the Module 3 capstone viva? :
#  [-0.02387593  0.00036229 -0.07705002 -0.03489099]
# the length of a vector:  384
# Refunds are processed within seven working days. :
#  [-0.06925714 -0.0039541   0.08934963  0.01417763]
