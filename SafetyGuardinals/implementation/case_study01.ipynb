# %%
import os
import json
from groq import Groq

from dotenv import load_dotenv
load_dotenv
api_key=os.getenv("api_key")

client=Groq(api_key=api_key)
# Out:
# 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
